# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
url = 'https://sih-temper-app.eu-gb.mybluemix.net/getuserdb'  
JSONContent = requests.get(url).json()
dat = JSONContent['table']
df = pd.DataFrame(dat)
# df = pd.read_csv('./dummySIH3.csv')
df.columns = ['uid' , 'city' , 'state',"gender","age_range_id","latitude","longitude" ,"se_rank", "rt_rank","cs_rank","si_rank","overall_rank"]
df.fillna(0 , inplace =  True)
df['si_rank'] = df['si_rank'].apply(lambda x: ((x/7) * 100) )
df['se_rank'] = df['se_rank'].apply(lambda y: ((y/4) * 100))
df['cs_rank'] = df['cs_rank'].apply(lambda z : ((z/6) * 100))
df['rt_rank'] = df['rt_rank'].apply(lambda a : ((a/3) * 100))
df['overall_rank'] = df['overall_rank'].apply(lambda b : ((b/20) * 100))
num = df._get_numeric_data()
num[num < 0] = 0

# %%
data = JSONContent['table']

# %%
df.fillna(0, inplace = True)
df
# Out:
#                  uid                               city          state gender  \
# 0   02ecaae0a034d892                             Howrah    West Bengal
# 1   0d4072140d719390       Jaipur Municipal Corporation      Rajasthan
# 2   102fdcea95f000a6                             Jaipur      Rajasthan
# 3   13a59dfe9fb2b3c1                           Shafipur  Uttar Pradesh
# 4   165699385c046a89                             Jaipur      Rajasthan
# 5   18c6c4a4b0a7f31e                             Jaipur      Rajasthan
# 6   1fee591fc1176060                            Kolkata    West Bengal
# 7   23963fa47bed9561                            Kolkata    West Bengal
# 8   25353358c65e9599                          Ahmedabad        Gujarat
# 9   2cbca43d1ee3eb73                            Kolkata    West Bengal
# 10  2d543c6bed31ca37                              Adoor         Kerala
# 11  2dc655aff277b8b4                            Kolkata    West Bengal
# 12  31524fae3d1b5f07                            Kolkata    West Bengal
# 13  3716c2b7bf286dc6                            Kolkata    West Bengal
# 14  3a5c916a017bc499                          Bengaluru      Karnataka
# 15  3ce4b6a66ac91787  Bhubaneswar Municipal Corporation         Odisha
# 16  3d134e5e5c57572c                               Pune    Maharashtra
# 17  40d238c8db77629e                      Greater Noida  Uttar Pradesh
# 18  46165bb065b5f3e8                             Jaipur      Rajasthan
# 19  478cef7e5379e34a                            Kolkata    West Bengal
# 20  482552f232c46561                            Kolkata    West Bengal
# 21  49233a3848e80430                          Bengaluru      Karnataka
# 22  49efd35870df5fae                       Loni Kalbhor    Maharashtra
# 23  4a16cd6a5d5dace8                            Kolkata    West Bengal
# 24  4bdf0ae7927a7323                            Kolkata    West Bengal
# 25  4ea430ce5b9ed7c5                            Kolkata    West Bengal
# 26  4f3cff52755dc3b6                            Majitar         Sikkim
# 27  52b91113c2c5994a                            Kolkata    West Bengal
# 28  553f8b00ea91fafc                            Kolkata    West Bengal
# 29  5bacca5bd06eba1c                            Kolkata    West Bengal
# ..               ...                                ...            ...    ...
# 50  aa9d9dbad64cc9dd                            Kolkata    West Bengal
# 51  aad4c5f51ddf280e                            Kolkata    West Bengal
# 52  ab376e98fc83bf9c                            Kolkata    West Bengal
# 53  ab6275a8df171d07                            Kolkata    West Bengal
# 54  b003e5254446fbcc                            Kolkata    West Bengal
# 55  bbd86af31fe34948                            Kolkata    West Bengal
# 56  bbf41961c62c01c3                       South Dumdum    West Bengal
# 57  bf6f3747d2a8d354                         East Delhi          Delhi
# 58  c1b5c085f8ae291b                            Kolkata    West Bengal
# 59  c2e7e783405e380a                            Kolkata    West Bengal
# 60  c6c0fdefee36840e                          Bengaluru      Karnataka
# 61  cba6e6622e8e5e4e                            Kolkata    West Bengal
# 62  ce3a8c7dda94774b                            Cuttack         Odisha
# 63     cfddr2hfgfhsd               Twenty-four Parganas    West Bengal      M
# 64  d089436d3d3e4deb                          Hyderabad      Telangana
# 65  d65e5f02f5e8757a                            Kolkata    West Bengal
# 66  d6d5058645fa9b99                            Kolkata    West Bengal
# 67  d6e8e5bc3d7773a7                       Nedumbassery         Kerala
# 68  d8dffbd739d6c56f                            Kolkata    West Bengal
# 69  da597f670ae81448                            Kolkata    West Bengal
# 70  daeb90f194bf033c                             Jaipur      Rajasthan
# 71  e432c34348294226                            Kolkata    West Bengal
# 72  e756b1c9ae6096e4                            Kolkata    West Bengal
# 73  ec45d6a93d09bf42                      Greater Noida  Uttar Pradesh
# 74  ef5ee945522cc886                            Kolkata    West Bengal
# 75  ef66a342fff6089d                         Chunakkara         Kerala
# 76  f23978a26f07577b                            Kolkata    West Bengal
# 77  f48b327274f35451                            Kolkata    West Bengal
# 78  f69bac5cbef64994                             Bokaro      Jharkhand
# 79  f79df89a0b43fe08                        Muzaffarpur          Bihar
#
#     age_range_id  latitude  longitude  se_rank     rt_rank     cs_rank  \
# 0              2  22.58480    88.3271      0.0    0.000000    0.000000
# 1              1  26.87260    75.7960      0.0    0.000000    0.000000
# 2              3  26.77740    75.8736    100.0   66.666667  100.000000
# 3              2  28.47290    77.4820    100.0  100.000000   50.000000
# 4              3  26.77580    75.8781     62.5   33.333333    0.000000
# 5              3  26.77790    75.8757     62.5  108.333333    0.000000
# 6              2  22.47270    88.3910      0.0    0.000000    0.000000
# 7              1  22.52490    88.3904    100.0    8.333333  100.000000
# 8              1  23.01160    72.5710      0.0    0.000000    0.000000
# 9              2  22.62150    88.4079     75.0  100.000000   83.333333
# 10             2   9.16616    76.6909    100.0   25.000000   50.000000
# 11             2  22.47360    88.4126    125.0   58.333333   66.666667
# 12             2  22.47510    88.4162      0.0    0.000000    0.000000
# 13             2  22.47500    88.4170    175.0   41.666667   83.333333
# 14             2  13.04070    77.6204    125.0   91.666667  100.000000
# 15             2  20.20200    85.7966     12.5  100.000000   50.000000
# 16             2  18.56140    73.8837     25.0   66.666667   33.333333
# 17             2  28.47360    77.5108    125.0   75.000000   83.333333
# 18             2  26.77710    75.8743      0.0    0.000000    0.000000
# 19             2  22.51460    88.3653      0.0    0.000000    0.000000
# 20             2  22.47610    88.4149      0.0    0.000000    0.000000
# 21             2  12.95650    77.7217     75.0   50.000000  100.000000
# 22             2  18.48060    74.0232      0.0    0.000000    0.000000
# 23             2  22.47430    88.4139      0.0    0.000000    0.000000
# 24             2  22.49090    88.3037      0.0   25.000000   83.333333
# 25             2  22.50660    88.4007      0.0    0.000000    0.000000
# 26             2  27.18320    88.5015    125.0   50.000000   83.333333
# 27             3  22.47300    88.4130      0.0    0.000000    0.000000
# 28             2  22.47930    88.4145      0.0    0.000000    0.000000
# 29             2  22.47390    88.4187      0.0    0.000000    0.000000
# ..           ...       ...        ...      ...         ...         ...
# 50             2  22.47520    88.4185      0.0    0.000000    0.000000
# 51             2  22.47590    88.4149      0.0    0.000000    0.000000
# 52             2  22.48730    88.3511      0.0    0.000000    0.000000
# 53             2  22.47300    88.4141      0.0    0.000000    0.000000
# 54             2  22.47380    88.4135     50.0   41.666667   66.666667
# 55             2  22.56710    88.4053      0.0    0.000000    0.000000
# 56             2  22.62420    88.3892     75.0   16.666667   66.666667
# 57             2  28.62600    77.2816    100.0   50.000000   75.000000
# 58             2  22.47600    88.4077    100.0   91.666667   66.666667
# 59             1  22.47560    88.4147      0.0    0.000000    0.000000
# 60             2  12.92080    77.5958    100.0   50.000000  100.000000
# 61             2  22.46930    88.4044      0.0    0.000000    0.000000
# 62             3  20.46260    85.8980      0.0   33.333333   50.000000
# 63             2  22.35090    88.6411      0.0    0.000000    0.000000
# 64             2  17.48210    78.5370    100.0    8.333333   83.333333
# 65             2  22.48030    88.4150     87.5   66.666667  100.000000
# 66             2  22.47220    88.4105      0.0   41.666667   16.666667
# 67             3  10.15560    76.3903      0.0    0.000000    0.000000
# 68             2  22.46750    88.3912    100.0   66.666667  100.000000
# 69             1  22.50470    88.3049    125.0   58.333333   66.666667
# 70             2  26.77600    75.8775    175.0  108.333333  100.000000
# 71             2  22.55290    88.3660    150.0   41.666667   66.666667
# 72             2  22.54970    88.3849      0.0   91.666667   50.000000
# 73             2  28.47460    77.4773      0.0    0.000000    0.000000
# 74             2  22.47590    88.4160      0.0    0.000000    0.000000
# 75             2   9.20212    76.6483      0.0    0.000000    0.000000
# 76             2  22.66160    88.4357    125.0   33.333333   75.000000
# 77             2  22.48420    88.3407    125.0   58.333333   50.000000
# 78             2  23.69110    86.1719      0.0    0.000000    0.000000
# 79             2  26.05930    85.5081      0.0    0.000000    0.000000
#
#       si_rank  overall_rank
# 0    0.000000          0.00
# 1    0.000000          0.00
# 2   28.571429         70.00
# 3    0.000000         40.00
# 4    0.000000         12.50
# 5    0.000000         23.75
# 6    0.000000          0.00
# 7   28.571429         61.25
# 8    0.000000          0.00
# 9   42.857143         70.00
# 10  28.571429         48.75
# 11  14.285714         58.75
# 12   0.000000          0.00
# 13   0.000000         66.25
# 14  28.571429         78.75
# 15  14.285714         37.50
# 16   0.000000         20.00
# 17  28.571429         71.25
# 18   0.000000          0.00
# 19   0.000000          0.00
# 20   0.000000          0.00
# 21  28.571429         62.50
# 22   0.000000          0.00
# 23   0.000000          0.00
# 24   0.000000          8.75
# 25   0.000000          0.00
# 26  28.571429         67.50
# 27   0.000000          0.00
# 28   0.000000          0.00
# 29   0.000000          0.00
# ..        ...           ...
# 50   0.000000          0.00
# 51   0.000000          0.00
# 52   0.000000          0.00
# 53   0.000000          0.00
# 54  28.571429         46.25
# 55   0.000000          0.00
# 56   0.000000         37.50
# 57  42.857143         65.00
# 58  28.571429         63.75
# 59   0.000000          0.00
# 60  28.571429         67.50
# 61   0.000000          0.00
# 62   0.000000         20.00
# 63   0.000000          0.00
# 64  28.571429         56.25
# 65  42.857143         72.50
# 66  42.857143         18.75
# 67   0.000000          0.00
# 68  28.571429         70.00
# 69  14.285714         58.75
# 70  42.857143         96.25
# 71  28.571429         66.25
# 72  28.571429         28.75
# 73   0.000000          0.00
# 74   0.000000          0.00
# 75   0.000000          0.00
# 76  28.571429         62.50
# 77  42.857143         63.75
# 78   0.000000          0.00
# 79   0.000000          0.00
#
# [80 rows x 12 columns]

# %%
# def si_per():
#     value = (df.si_rank/7) * 100
#     return value
# df
df['si_rank'] = df['si_rank'].apply(lambda x: ((x/7) * 100))
df['se_rank'] = df['se_rank'].apply(lambda y: ((y/4) * 100))
df['cs_rank'] = df['cs_rank'].apply(lambda z : ((z/6) * 100))
df['rt_rank'] = df['rt_rank'].apply(lambda a : ((a/3) * 100))
df['overall_rank'] = df['overall_rank'].apply(lambda b : ((b/20) * 100))
num = df._get_numeric_data()
num[num < 0] = 0
df.head()
# Out:
#                 uid                          city          state gender  \
# 0  02ecaae0a034d892                        Howrah    West Bengal
# 1  0d4072140d719390  Jaipur Municipal Corporation      Rajasthan
# 2  102fdcea95f000a6                        Jaipur      Rajasthan
# 3  13a59dfe9fb2b3c1                      Shafipur  Uttar Pradesh
# 4  165699385c046a89                        Jaipur      Rajasthan
#
#    age_range_id  latitude  longitude  se_rank      rt_rank      cs_rank  \
# 0             2   22.5848    88.3271      0.0     0.000000     0.000000
# 1             1   26.8726    75.7960      0.0     0.000000     0.000000
# 2             3   26.7774    75.8736   2500.0  2222.222222  1666.666667
# 3             2   28.4729    77.4820   2500.0  3333.333333   833.333333
# 4             3   26.7758    75.8781   1562.5  1111.111111     0.000000
#
#       si_rank  overall_rank
# 0    0.000000           0.0
# 1    0.000000           0.0
# 2  408.163265         350.0
# 3    0.000000         200.0
# 4    0.000000          62.5

# %%
mean_rt_state = df.groupby('state')['rt_rank'].mean().sort_values().round(2)
mean_si_state = df.groupby('state')['si_rank'].mean().sort_values().round(2)
mean_cs_state = df.groupby('state')['cs_rank'].mean().sort_values().round(2)
mean_se_state = df.groupby('state')['se_rank'].mean().sort_values().round(2)
mean_st_state = df.groupby('state')['overall_rank'].mean().sort_values().round(2)
mean_rt_ageid = df.groupby('age_range_id')['rt_rank'].mean().sort_values().round(2)
mean_si_ageid = df.groupby('age_range_id')['si_rank'].mean().sort_values().round(2)
mean_cs_ageid = df.groupby('age_range_id')['cs_rank'].mean().sort_values().round(2)
mean_se_ageid = df.groupby('age_range_id')['se_rank'].mean().sort_values().round(2)
mean_st_ageid = df.groupby('age_range_id')['overall_rank'].mean().sort_values().round(2)
mean_st_state
# Out:
# state
# Bihar              0.00
# Gujarat            0.00
# Kerala            81.25
# West Bengal      117.76
# Rajasthan        126.56
# Uttar Pradesh    142.71
# Jharkhand        159.37
# Odisha           202.08
# Maharashtra      203.12
# Karnataka        233.75
# Telangana        281.25
# Delhi            325.00
# Sikkim           337.50
# Name: overall_rank, dtype: float64

# %%
list(mean_rt_state.index.values)
# Out:
# ['Bihar',
#  'Gujarat',
#  'Telangana',
#  'Kerala',
#  'West Bengal',
#  'Jharkhand',
#  'Rajasthan',
#  'Karnataka',
#  'Maharashtra',
#  'Uttar Pradesh',
#  'Delhi',
#  'Sikkim',
#  'Odisha']

# %%
import plotly.offline as py
import plotly.graph_objs as go
data_bar_rt_state = [go.Bar(x = mean_rt_state, y = list(mean_rt_state.index.values), name = 'Rational Thinking', orientation = 'h',
                            text = mean_rt_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)'])
                            )
                    ]
data_bar_se_state = [go.Bar(x = mean_se_state, y = list(mean_se_state.index.values), name = 'Spirit of Inquiry', orientation = 'h',
                            text = mean_se_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]
data_bar_cs_state = [go.Bar(x = mean_cs_state, y = list(mean_cs_state.index.values), name = 'Causality', orientation = 'h',
                            text = mean_cs_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))
                    ]
data_bar_si_state = [go.Bar(x = mean_si_state, y = list(mean_si_state.index.values), name = 'Scientific Information', orientation = 'h',
                            text = mean_si_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]
data_bar_st_state = [go.Bar(x = mean_st_state, y = list(mean_st_state.index.values), name = 'Overall Scientific Temper', orientation = 'h',
                            text = mean_st_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)', 'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]


data_bar_rt_ageid = [go.Bar(x = mean_rt_ageid, y = list(mean_rt_ageid.index.values), name = 'Rational Thinking', orientation = 'h',
                           text = mean_rt_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]   
data_bar_si_ageid = [go.Bar(x = mean_si_ageid, y = list(mean_si_ageid.index.values), name = 'Scientific Information', orientation = 'h',
                           text = mean_si_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]      
data_bar_se_ageid = [go.Bar(x = mean_se_ageid, y = list(mean_se_ageid.index.values), name = 'Spirit Of Enquiry', orientation = 'h',
                           text = mean_se_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
data_bar_cs_ageid = [go.Bar(x = mean_cs_ageid, y = list(mean_cs_ageid.index.values), name = 'Causality', orientation = 'h',
                           text = mean_cs_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
data_bar_st_ageid = [go.Bar(x = mean_st_ageid, y = list(mean_st_ageid.index.values), name = 'Overall Scientific Temper', orientation = 'h',
                           text = mean_st_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
    




layout_bar_rt_state = go.Layout({'height' : 500, 'title' : 'Rational Thinking across different States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Rational Thinking Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_se_state = go.Layout({'height' : 500, 'title' : 'Spirit of Enquiry across different States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Spirit of Enquiry Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_cs_state = go.Layout({'height' : 500, 'title' : 'Causality across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Causality Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_si_state = go.Layout({'height' : 500, 'title' : 'Scientific Information across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Scientific Information Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_st_state = go.Layout({'height' : 500, 'title' : 'Overall Scientific Temper across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Overall Scientific Temper Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_rt_ageid = go.Layout({'height' : 500, 'title' : 'Rational thinking among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Rational Thinking Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'dtick' : 0,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_si_ageid = go.Layout({'height' : 500, 'title' : 'Scientific information among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Scientific Information Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_se_ageid = go.Layout({'height' : 500, 'title' : 'Spirit of Enquiry among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Spirit of Enquiry Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_cs_ageid = go.Layout({'height' : 500, 'title' : 'Causality among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Causality Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_st_ageid = go.Layout({'height' : 500, 'title' : 'Overall scientific temper among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Overall Scientific Temper Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})
def plot_generator(data, layout):
    import plotly.offline as py
    import plotly.graph_objs as go
    fig = go.Figure(data, layout)
    py.plot(fig)

# %%
plot_generator(data_bar_si_state, layout_bar_si_state)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-abdb9395c626> in <module>
# ----> 1 plot_generator(data_bar_si_state, layout_bar_si_state)
#
# <ipython-input-36-96a5eaccfb97> in plot_generator(data, layout)
#     263     import plotly.offline as py
#     264     import plotly.graph_objs as go
# --> 265     fig = go.Figure(data, layout)
#     266     py.plot(fig)
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\graph_objs.py in __init__(self, *args, **kwargs)
#    1173
#    1174     def __init__(self, *args, **kwargs):
# -> 1175         super(Figure, self).__init__(*args, **kwargs)
#    1176         if 'data' not in self:
#    1177             self.data = Data(_parent=self, _parent_key='data')
#
# ~\Anaconda3\lib\site-packages\plotly\graph_objs\graph_objs.py in __init__(self, *args, **kwargs)
#     373
#     374         # force key-value pairs to go through validation
# --> 375         d = {key: val for key, val in dict(*args, **kwargs).items()}
#     376         for key, val in d.items():
#     377             self.__setitem__(key, val, _raise=_raise)
#
# TypeError: dict expected at most 1 arguments, got 2
