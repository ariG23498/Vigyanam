# %%
import numpy as np
import pandas as pd
import requests
import json

# %%
#fetching the data
url = 'https://sih-temper-app.eu-gb.mybluemix.net/getuserdb'   #put the required url
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4, sort_keys = True)

# %%
data = JSONContent['table']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2be394f363f1> in <module>()
# ----> 1 data = JSONContent['table']
#
# NameError: name 'JSONContent' is not defined

# %%
df = pd.DataFrame(data)
df.columns = ['uid', 'city' , 'state', 'gender', "age_range_id", "latitude", "longitude", "si_rank", "se_rank","cs_rank","rt_rank","overall_rank"]
df.head()
# Out:
#                 uid                          city          state gender  \
# 0  02ecaae0a034d892                        Howrah    West Bengal
# 1  0d4072140d719390  Jaipur Municipal Corporation      Rajasthan
# 2  102fdcea95f000a6                        Jaipur      Rajasthan
# 3  13a59dfe9fb2b3c1                      Shafipur  Uttar Pradesh
# 4  165699385c046a89                        Jaipur      Rajasthan
#
#    age_range_id  latitude  longitude  si_rank  se_rank  cs_rank  rt_rank  \
# 0             2   22.5848    88.3271      NaN      NaN      NaN      NaN
# 1             1   26.8726    75.7960      NaN      NaN      NaN      NaN
# 2             3   26.7774    75.8736      4.0      2.0      6.0      2.0
# 3             2   28.4729    77.4820      4.0      3.0      3.0     -2.0
# 4             3   26.7758    75.8781      2.5      1.0      0.0     -1.0
#
#    overall_rank
# 0           NaN
# 1           NaN
# 2          14.0
# 3           8.0
# 4           2.5

# %%
# def si_per():
#     value = (df.si_rank/7) * 100
#     return value
# df
df['si_rank'] = df['si_rank'].apply(lambda x: ((x/7) * 100))
df['se_rank'] = df['se_rank'].apply(lambda y: ((y/4) * 100))
df['cs_rank'] = df['cs_rank'].apply(lambda z : ((z/6) * 100))
df['rt_rank'] = df['rt_rank'].apply(lambda a : ((a/3) * 100))
df['overall_rank'] = df['overall_rank'].apply(lambda b : ((b/20) * 100))
num = df._get_numeric_data()
num[num < 0] = 0
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e03cfe8f14ec> in <module>()
#       3 #     return value
#       4 # df
# ----> 5 df['si_rank'] = df['si_rank'].apply(lambda x: ((x/7) * 100))
#       6 df['se_rank'] = df['se_rank'].apply(lambda y: ((y/4) * 100))
#       7 df['cs_rank'] = df['cs_rank'].apply(lambda z : ((z/6) * 100))
#
# NameError: name 'df' is not defined

# %%
mean_rt_state = dfff.groupby('state')['rt_per'].mean().sort_values().round(2)
mean_si_state = dfff.groupby('state')['si_per'].mean().sort_values().round(2)
mean_cs_state = dfff.groupby('state')['cs_per'].mean().sort_values().round(2)
mean_se_state = dfff.groupby('state')['se_per'].mean().sort_values().round(2)
mean_st_state = dfff.groupby('state')['overall_per'].mean().sort_values().round(2)
mean_rt_ageid = dfff.groupby('age_range_id')['rt_per'].mean().sort_values().round(2)
mean_si_ageid = dfff.groupby('age_range_id')['si_per'].mean().sort_values().round(2)
mean_cs_ageid = dfff.groupby('age_range_id')['cs_per'].mean().sort_values().round(2)
mean_se_ageid = dfff.groupby('age_range_id')['se_per'].mean().sort_values().round(2)
mean_st_ageid = dfff.groupby('age_range_id')['overall_per'].mean().sort_values().round(2)
mean_st_state
# Out:
# state
# Bihar             0.00
# Gujarat           0.00
# Kerala           16.25
# West Bengal      23.55
# Rajasthan        25.31
# Uttar Pradesh    28.54
# Jharkhand        31.87
# Odisha           40.42
# Maharashtra      40.62
# Karnataka        46.75
# Telangana        56.25
# Delhi            65.00
# Sikkim           67.50
# Name: overall_per, dtype: float64

# %%
list(mean_rt_state.index.values)
# Out:
# ['Bihar',
#  'Gujarat',
#  'Rajasthan',
#  'Kerala',
#  'Uttar Pradesh',
#  'West Bengal',
#  'Jharkhand',
#  'Maharashtra',
#  'Odisha',
#  'Karnataka',
#  'Sikkim',
#  'Telangana',
#  'Delhi']

# %%
import plotly.offline as py
import plotly.graph_objs as go
data_bar_rt_state = [go.Bar(x = mean_rt_state, y = list(mean_rt_state.index.values), name = 'Rational Thinking', orientation = 'h',
                            text = mean_rt_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)'])
                            )
                    ]
data_bar_se_state = [go.Bar(x = mean_se_state, y = list(mean_se_state.index.values), name = 'Spirit of Inquiry', orientation = 'h',
                            text = mean_se_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]
data_bar_cs_state = [go.Bar(x = mean_cs_state, y = list(mean_cs_state.index.values), name = 'Causality', orientation = 'h',
                            text = mean_cs_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))
                    ]
data_bar_si_state = [go.Bar(x = mean_si_state, y = list(mean_si_state.index.values), name = 'Scientific Information', orientation = 'h',
                            text = mean_si_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)',  'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]
data_bar_st_state = [go.Bar(x = mean_st_state, y = list(mean_st_state.index.values), name = 'Overall Scientific Temper', orientation = 'h',
                            text = mean_st_state,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)',
                                            'rgb(0,255,255)', 'rgb(255,0,255)', 'rgb(0,128,128)', 'rgb(128,0,0)',
                                            'rgb(255,69,0)', 'rgb(255,140,0)', 'rgb(0,100,0)', 'rgb(128,128,0)',
                                                 'rgb(147,112,219)', 'rgb(210,105,30)', 'rgb(188,143,143)',
                                                 'rgb(105,105,105)']))]


data_bar_rt_ageid = [go.Bar(x = mean_rt_ageid, y = list(mean_rt_ageid.index.values), name = 'Rational Thinking', orientation = 'h',
                           text = mean_rt_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]   
data_bar_si_ageid = [go.Bar(x = mean_si_ageid, y = list(mean_si_ageid.index.values), name = 'Scientific Information', orientation = 'h',
                           text = mean_si_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]      
data_bar_se_ageid = [go.Bar(x = mean_se_ageid, y = list(mean_se_ageid.index.values), name = 'Spirit Of Enquiry', orientation = 'h',
                           text = mean_se_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
data_bar_cs_ageid = [go.Bar(x = mean_cs_ageid, y = list(mean_cs_ageid.index.values), name = 'Causality', orientation = 'h',
                           text = mean_cs_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
data_bar_st_ageid = [go.Bar(x = mean_st_ageid, y = list(mean_st_ageid.index.values), name = 'Overall Scientific Temper', orientation = 'h',
                           text = mean_st_ageid,
                            textposition = 'auto',
                            marker = dict(
                                           color=['rgb(255,0,0)', 'rgb(0,255,0)',
                                                  'rgb(0,0,255)', 'rgb(255,255,0)']))]     
    




layout_bar_rt_state = go.Layout({'height' : 500, 'title' : 'Rational Thinking across different States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Rational Thinking Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_se_state = go.Layout({'height' : 500, 'title' : 'Spirit of Enquiry across different States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Spirit of Enquiry Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_cs_state = go.Layout({'height' : 500, 'title' : 'Causality across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Causality Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_si_state = go.Layout({'height' : 500, 'title' : 'Scientific Information across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Scientific Information Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})
layout_bar_st_state = go.Layout({'height' : 500, 'title' : 'Overall Scientific Temper across various States',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Overall Scientific Temper Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'State',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_rt_ageid = go.Layout({'height' : 500, 'title' : 'Rational thinking among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Rational Thinking Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'dtick' : 0,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_si_ageid = go.Layout({'height' : 500, 'title' : 'Scientific information among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Scientific Information Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_se_ageid = go.Layout({'height' : 500, 'title' : 'Spirit of Enquiry among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Spirit of Enquiry Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_cs_ageid = go.Layout({'height' : 500, 'title' : 'Causality among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Causality Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})

layout_bar_st_ageid = go.Layout({'height' : 500, 'title' : 'Overall scientific temper among age slab groups',
                                 'titlefont' : {'size' : 30}, 'xaxis' : {'zeroline' : True,
                                                                         'showline' : True,
                                                                         'zerolinewidth' : 4,
                                                                         'linewidth' : 6,
                                                                         'domain' : [0.2, 0.8],
                                                                         'title' : 'Overall Scientific Temper Score(Percentage)',
                                                                         'ticklen' : 5,
                                                                         'tickwidth' : 3,
                                                                         'dtick' : 10,
                                                                         'titlefont' : {'size' : 22}},
                                                                         'yaxis' : {'zeroline' : True,
                                                                                    'showline' : True,
                                                                                    'zerolinewidth' : 4,
                                                                                    'linewidth' : 6,
                                                                                    'title' : 'Age Slab',
                                                                                    'titlefont' : {'size' : 22}}})
def plot_generator(data, layout):
    import plotly.offline as py
    import plotly.graph_objs as go
    fig = go.Figure(data, layout)
    py.plot(fig)

# %%
plot_generator(data_bar_si_state, layout_bar_si_state)
